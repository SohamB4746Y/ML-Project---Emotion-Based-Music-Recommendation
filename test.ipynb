# %%
import  numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df=pd.read_csv(r'C:\Softwares\VSCODE\PROGRAMS\Python\ML\Dataset\playlists.csv')
df_songs=pd.read_csv(r'C:\Softwares\VSCODE\PROGRAMS\Python\ML\Dataset\genres_v2.csv')
df.head()
# Out:
# C:\Users\Aravind Chintalapati\AppData\Local\Temp\ipykernel_25384\1936135902.py:2: DtypeWarning: Columns (19) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_songs=pd.read_csv(r'C:\Softwares\VSCODE\PROGRAMS\Python\ML\Dataset\genres_v2.csv')
#                  Playlist      Genre
# 0  19WuHd4MxWLzE1fpMmw4S4  Dark Trap
# 1  6XyR8uzgkSoDzHuOxxRtLH  Dark Trap
# 2  37Ij3ofyhvEhFEH8YZMZ2X  Dark Trap
# 3  07zTlfPpsxeoWdumbkNWMI  Dark Trap
# 4  2dClSRLsnptdkDQnpi5H2f  Dark Trap

# %%
df_songs.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.831   0.814    2    -7.364     1       0.4200        0.0598
# 1         0.719   0.493    8    -7.230     1       0.0794        0.4010
# 2         0.850   0.893    5    -4.783     1       0.0623        0.0138
# 3         0.476   0.781    0    -4.710     1       0.1030        0.0237
# 4         0.798   0.624    2    -7.668     1       0.2930        0.2170
#
#    instrumentalness  liveness  valence  ...                      id  \
# 0          0.013400    0.0556   0.3890  ...  2Vc6NJ9PW9gD9q343XFRKx
# 1          0.000000    0.1180   0.1240  ...  7pgJBLVz5VmnL7uGHmRj6p
# 2          0.000004    0.3720   0.0391  ...  0vSWgAlfpye0WCGeNmuNhy
# 3          0.000000    0.1140   0.1750  ...  0VSXnJqQkwuH2ei1nOQ1nu
# 4          0.000000    0.1660   0.5910  ...  4jCeguq9rMTlbMmPHuO7S3
#
#                                     uri  \
# 0  spotify:track:2Vc6NJ9PW9gD9q343XFRKx
# 1  spotify:track:7pgJBLVz5VmnL7uGHmRj6p
# 2  spotify:track:0vSWgAlfpye0WCGeNmuNhy
# 3  spotify:track:0VSXnJqQkwuH2ei1nOQ1nu
# 4  spotify:track:4jCeguq9rMTlbMmPHuO7S3
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/2Vc6NJ9PW9gD...
# 1  https://api.spotify.com/v1/tracks/7pgJBLVz5Vmn...
# 2  https://api.spotify.com/v1/tracks/0vSWgAlfpye0...
# 3  https://api.spotify.com/v1/tracks/0VSXnJqQkwuH...
# 4  https://api.spotify.com/v1/tracks/4jCeguq9rMTl...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/2Vc6...      124539
# 1  https://api.spotify.com/v1/audio-analysis/7pgJ...      224427
# 2  https://api.spotify.com/v1/audio-analysis/0vSW...       98821
# 3  https://api.spotify.com/v1/audio-analysis/0VSX...      123661
# 4  https://api.spotify.com/v1/audio-analysis/4jCe...      123298
#
#   time_signature      genre                                      song_name  \
# 0              4  Dark Trap                            Mercury: Retrograde
# 1              4  Dark Trap                                      Pathology
# 2              4  Dark Trap                                       Symbiote
# 3              3  Dark Trap  ProductOfDrugs (Prod. The Virus and Antidote)
# 4              4  Dark Trap                                          Venom
#
#   Unnamed: 0 title
# 0        NaN   NaN
# 1        NaN   NaN
# 2        NaN   NaN
# 3        NaN   NaN
# 4        NaN   NaN
#
# [5 rows x 22 columns]

# %%
unique_genres = df_songs['genre'].unique()
print(unique_genres)
# Out:
# ['Dark Trap' 'Underground Rap' 'Trap Metal' 'Emo' 'Rap' 'RnB' 'Pop'
#  'Hiphop' 'techhouse' 'techno' 'trance' 'psytrance' 'trap' 'dnb'
#  'hardstyle']

# %%
selected_genres = ['Dark Trap', 'Underground Rap', 'Trap Metal', 'Emo', 'Rap', 'RnB', 'Pop', 'Hiphop']
df_songs = df_songs[df_songs['genre'].isin(selected_genres)]

# Optional: Verify the unique genres after filtering
print(df_songs['genre'].unique())
# Out:
# ['Dark Trap' 'Underground Rap' 'Trap Metal' 'Emo' 'Rap' 'RnB' 'Pop'
#  'Hiphop']

# %%
selected_genres = ['Dark Trap', 'Underground Rap', 'Trap Metal', 'Emo', 'Rap', 'RnB', 'Pop', 'Hiphop']
df_songs = df_songs[df_songs['genre'].isin(selected_genres)]

# Verifying the unique genres after filtering
print(df_songs['genre'].unique())
df_songs.head()
# Out:
# ['Dark Trap' 'Underground Rap' 'Trap Metal' 'Emo' 'Rap' 'RnB' 'Pop'
#  'Hiphop']
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.831   0.814    2    -7.364     1       0.4200        0.0598
# 1         0.719   0.493    8    -7.230     1       0.0794        0.4010
# 2         0.850   0.893    5    -4.783     1       0.0623        0.0138
# 3         0.476   0.781    0    -4.710     1       0.1030        0.0237
# 4         0.798   0.624    2    -7.668     1       0.2930        0.2170
#
#    instrumentalness  liveness  valence  ...                      id  \
# 0          0.013400    0.0556   0.3890  ...  2Vc6NJ9PW9gD9q343XFRKx
# 1          0.000000    0.1180   0.1240  ...  7pgJBLVz5VmnL7uGHmRj6p
# 2          0.000004    0.3720   0.0391  ...  0vSWgAlfpye0WCGeNmuNhy
# 3          0.000000    0.1140   0.1750  ...  0VSXnJqQkwuH2ei1nOQ1nu
# 4          0.000000    0.1660   0.5910  ...  4jCeguq9rMTlbMmPHuO7S3
#
#                                     uri  \
# 0  spotify:track:2Vc6NJ9PW9gD9q343XFRKx
# 1  spotify:track:7pgJBLVz5VmnL7uGHmRj6p
# 2  spotify:track:0vSWgAlfpye0WCGeNmuNhy
# 3  spotify:track:0VSXnJqQkwuH2ei1nOQ1nu
# 4  spotify:track:4jCeguq9rMTlbMmPHuO7S3
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/2Vc6NJ9PW9gD...
# 1  https://api.spotify.com/v1/tracks/7pgJBLVz5Vmn...
# 2  https://api.spotify.com/v1/tracks/0vSWgAlfpye0...
# 3  https://api.spotify.com/v1/tracks/0VSXnJqQkwuH...
# 4  https://api.spotify.com/v1/tracks/4jCeguq9rMTl...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/2Vc6...      124539
# 1  https://api.spotify.com/v1/audio-analysis/7pgJ...      224427
# 2  https://api.spotify.com/v1/audio-analysis/0vSW...       98821
# 3  https://api.spotify.com/v1/audio-analysis/0VSX...      123661
# 4  https://api.spotify.com/v1/audio-analysis/4jCe...      123298
#
#   time_signature      genre                                      song_name  \
# 0              4  Dark Trap                            Mercury: Retrograde
# 1              4  Dark Trap                                      Pathology
# 2              4  Dark Trap                                       Symbiote
# 3              3  Dark Trap  ProductOfDrugs (Prod. The Virus and Antidote)
# 4              4  Dark Trap                                          Venom
#
#   Unnamed: 0 title
# 0        NaN   NaN
# 1        NaN   NaN
# 2        NaN   NaN
# 3        NaN   NaN
# 4        NaN   NaN
#
# [5 rows x 22 columns]

# %%
df_songs.to_csv(r'C:\Softwares\VSCODE\PROGRAMS\Python\ML\Dataset\finaldataset2.csv')

# %%
#Dropping unnecessary columns
df_songs = df_songs.drop(columns=['type', 'id', 'uri', 'track_href', 'analysis_url', 'Unnamed: 0'])
df_songs.columns.tolist()
# Out:
# ['danceability',
#  'energy',
#  'key',
#  'loudness',
#  'mode',
#  'speechiness',
#  'acousticness',
#  'instrumentalness',
#  'liveness',
#  'valence',
#  'tempo',
#  'duration_ms',
#  'time_signature',
#  'genre',
#  'song_name',
#  'title']

# %%
print(df_songs.size)
# Out:
# 344400

# %%
from sklearn.mixture import GaussianMixture
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_score, davies_bouldin_score, calinski_harabasz_score
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# features
features = ['valence', 'energy', 'danceability', 'tempo']
X = df_songs[features].dropna()

# Scaling them 
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# PCA
pca = PCA(n_components=2, random_state=42)
X_reduced = pca.fit_transform(X_scaled)

print(f"Explained variance by PCA components: {pca.explained_variance_ratio_.sum():.2%}")

#Gaussian Mixture Model 
gmm = GaussianMixture(n_components=4, random_state=42, n_init=5, covariance_type='full')
gmm_labels = gmm.fit_predict(X_reduced)

# Add cluster labels to DataFrame
df_songs.loc[X.index, 'cluster'] = gmm_labels

# Evaluation Metrics
silhouette = silhouette_score(X_reduced, gmm_labels)
db_index = davies_bouldin_score(X_reduced, gmm_labels)
ch_index = calinski_harabasz_score(X_reduced, gmm_labels)
#Scores to check 
print("\n📊 GMM Evaluation Metrics (on PCA-reduced data):")
print(f"Silhouette Score: {silhouette:.3f}")
print(f"Davies-Bouldin Index: {db_index:.3f} (lower is better)")
print(f"Calinski-Harabasz Index: {ch_index:.2f} (higher is better)")

# Mood Labeling
mood_labels = {
    0: "Sad / Mellow",
    1: "Energetic / Party",
    2: "Happy / Chill",
    3: "Calm / Content"
}
df_songs.loc[X.index, 'mood_label'] = df_songs.loc[X.index, 'cluster'].map(mood_labels)

# Visualization
plt.figure(figsize=(8,6))
sns.scatterplot(x=X_reduced[:, 0], y=X_reduced[:, 1],
                hue=df_songs.loc[X.index, 'mood_label'],
                palette='viridis', alpha=0.7)
plt.title('🎵 GMM Mood Clusters (PCA Reduced)')
plt.xlabel('PCA Component 1')
plt.ylabel('PCA Component 2')
plt.legend(title="Mood", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# Feature Distributions
sns.pairplot(df_songs.loc[X.index, features + ['mood_label']],
             hue='mood_label', palette='viridis', diag_kind='kde', plot_kws={'alpha':0.5})
plt.suptitle('Feature Distributions by Mood Cluster', y=1.02)
plt.show()

# Save Results
output_path = "songs_with_moods_fixed.csv"
df_songs.to_csv(output_path, index=False)
print(f"\n✅ Clustered songs (with mood labels) saved to: {output_path}")



# Example usage:
# get_songs_by_mood("Calm")
# Out:
# Explained variance by PCA components: 64.09%
#
# 📊 GMM Evaluation Metrics (on PCA-reduced data):
# Silhouette Score: 0.331
# Davies-Bouldin Index: 0.946 (lower is better)
# Calinski-Harabasz Index: 14347.81 (higher is better)
#
# 📊 GMM Evaluation Metrics (on PCA-reduced data):
# Silhouette Score: 0.331
# Davies-Bouldin Index: 0.946 (lower is better)
# Calinski-Harabasz Index: 14347.81 (higher is better)
# C:\Users\Aravind Chintalapati\AppData\Local\Temp\ipykernel_25384\493882446.py:58: UserWarning: Glyph 127925 (\N{MUSICAL NOTE}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# c:\Softwares\Python\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 127925 (\N{MUSICAL NOTE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# ✅ Clustered songs (with mood labels) saved to: songs_with_moods_fixed.csv

# %%
# ========== 9️⃣ Query Function ==========
def get_songs_by_mood(mood):
    mood = mood.lower()
    results = df_songs[df_songs['mood_label'].str.lower().str.contains(mood)]
    if results.empty:
        print(f"No songs found for mood '{mood}'. Try one of these:")
        print(df_songs['mood_label'].unique())
    else:
        print(f"\n🎶 Songs for mood '{mood}':")
        print(results[['song_name', 'title', 'mood_label']].head(10))  # show sample
    return results

# %%
get_songs_by_mood("Happy / Chill")
# Out:
# 🎶 Songs for mood 'happy / chill':
#                                    song_name title     mood_label
# 0                        Mercury: Retrograde   NaN  Happy / Chill
# 4                                      Venom   NaN  Happy / Chill
# 9                                  Andromeda   NaN  Happy / Chill
# 19                                     Paris   NaN  Happy / Chill
# 21                            High 'N Mighty   NaN  Happy / Chill
# 28                                BLUE JUICE   NaN  Happy / Chill
# 39                                  Kybalion   NaN  Happy / Chill
# 43  Nightmare Choir (I Been Asleep Too Long)   NaN  Happy / Chill
# 48                                   Paralax   NaN  Happy / Chill
# 59                           Pound for Pound   NaN  Happy / Chill
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0             0.831   0.814    2    -7.364     1       0.4200       0.05980
# 4             0.798   0.624    2    -7.668     1       0.2930       0.21700
# 9             0.893   0.907   11   -10.406     1       0.3670       0.15200
# 19            0.849   0.648    7    -6.188     1       0.0832       0.07250
# 21            0.876   0.768    7    -6.606     1       0.2010       0.11200
# ...             ...     ...  ...       ...   ...          ...           ...
# 21516         0.812   0.658    6    -6.834     1       0.1570       0.00607
# 21517         0.719   0.444    4    -7.854     0       0.1900       0.05440
# 21522         0.785   0.648    7    -6.907     1       0.2790       0.01570
# 21523         0.747   0.832    3    -5.737     0       0.1850       0.23300
# 21524         0.816   0.775   11    -3.323     1       0.2340       0.16000
#
#        instrumentalness  liveness  valence    tempo  duration_ms  \
# 0              0.013400    0.0556    0.389  156.985       124539
# 4              0.000000    0.1660    0.591  147.988       123298
# 9              0.031100    0.5580    0.302  199.942       121979
# 19             0.005920    0.0984    0.196  212.150       111020
# 21             0.000012    0.2830    0.720  111.958       124676
# ...                 ...       ...      ...      ...          ...
# 21516          0.000000    0.1340    0.514  191.978       217187
# 21517          0.000000    0.1700    0.724  179.820       257853
# 21522          0.001980    0.1000    0.506  184.160       271867
# 21523          0.000014    0.1300    0.733  188.760       182040
# 21524          0.000310    0.0543    0.527  186.862       270587
#
#        time_signature      genre  \
# 0                   4  Dark Trap
# 4                   4  Dark Trap
# 9                   4  Dark Trap
# 19                  4  Dark Trap
# 21                  5  Dark Trap
# ...               ...        ...
# 21516               4     Hiphop
# 21517               4     Hiphop
# 21522               4     Hiphop
# 21523               4     Hiphop
# 21524               4     Hiphop
#
#                                                song_name title  cluster  \
# 0                                    Mercury: Retrograde   NaN      2.0
# 4                                                  Venom   NaN      2.0
# 9                                              Andromeda   NaN      2.0
# 19                                                 Paris   NaN      2.0
# 21                                        High 'N Mighty   NaN      2.0
# ...                                                  ...   ...      ...
# 21516                                         Get $ Paid   NaN      2.0
# 21517  I'm Sorry Baby (Remix) [feat. Wadz & Talkbox P...   NaN      2.0
# 21522                                        Born 2 Live   NaN      2.0
# 21523                                      Can't Hold On   NaN      2.0
# 21524                                       Still D.R.E.   NaN      2.0
#
#           mood_label
# 0      Happy / Chill
# 4      Happy / Chill
# 9      Happy / Chill
# 19     Happy / Chill
# 21     Happy / Chill
# ...              ...
# 21516  Happy / Chill
# 21517  Happy / Chill
# 21522  Happy / Chill
# 21523  Happy / Chill
# 21524  Happy / Chill
#
# [6847 rows x 18 columns]

# %%
def predict_mood(song_features):
    """
    Predict the mood for a song given its features.
    
    song_features: dict with keys as feature names (e.g., {'valence': 0.5, 'energy': 0.8, ...})
    """
    # Convert to DataFrame for consistency
    song_df = pd.DataFrame([song_features])
    
    # Scale using the same scaler
    song_scaled = scaler.transform(song_df)
    
    # Apply PCA using the same pca
    song_reduced = pca.transform(song_scaled)
    
    # Predict cluster with GMM
    cluster = gmm.predict(song_reduced)[0]
    
    # Map to mood label
    mood = mood_labels.get(cluster, "Unknown")
    
    return mood, cluster

#Testing
test_song = {
    'valence': 0.16,  
    'energy': 0.39,
    'danceability': 0.53,
    'tempo': 90.0
}
predicted_mood, predicted_cluster = predict_mood(test_song)
print(f"Predicted Mood: {predicted_mood}")
print(f"Predicted Cluster: {predicted_cluster}")
# Out:
# Predicted Mood: Sad / Mellow
# Predicted Cluster: 0

# %%
cluster_analysis = df_songs.groupby('cluster')[features].agg(['mean', 'std', 'count'])
print(cluster_analysis)
# Out:
#           valence                    energy                 danceability  \
#              mean       std count      mean       std count         mean
# cluster
# 0.0      0.192150  0.120022  4628  0.578383  0.156659  4628     0.568449
# 1.0      0.357813  0.181395  3851  0.834305  0.110243  3851     0.479336
# 2.0      0.652448  0.157919  6847  0.732663  0.122269  6847     0.754004
# 3.0      0.362927  0.163888  6199  0.522754  0.127853  6199     0.787400
#
#                               tempo
#               std count        mean        std count
# cluster
# 0.0      0.112039  4628  146.369525  27.768111  4628
# 1.0      0.116716  3851  163.174479  25.872537  3851
# 2.0      0.100472  6847  160.784634  28.175953  6847
# 3.0      0.086466  6199  137.755730  26.299255  6199

# %%
import joblib

# Save the trained GMM model
joblib.dump(gmm, "gmm_mood_model.pkl")

# Optionally, save the scaler and PCA too
joblib.dump(scaler, "scaler.pkl")
joblib.dump(pca, "pca.pkl")
# Out:
# ['pca.pkl']
